# %%
#import libraries and packages
import sys
import os
from fastapi import FastAPI
from pydantic import BaseModel

#import classes
from agents.travel_planner_agent import TravelPlannerAgent
from agents.content_curator_agent import ContentCuratorAgent
from backend.database import init_db, save_session
from backend.schemas import TravelRequest, TravelResponse
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 8
#       5 from pydantic import BaseModel
#       7 #import classes
# ----> 8 from agents.travel_planner_agent import TravelPlannerAgent
#       9 from agents.content_curator_agent import ContentCuratorAgent
#      10 from backend.database import init_db, save_session
#
# ImportError: cannot import name 'TravelPlannerAgent' from 'agents.travel_planner_agent' (d:\InterviewPrep\Projects\the_travel_create_agent\agents\travel_planner_agent.py)
